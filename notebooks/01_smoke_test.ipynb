# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\aispire\python-env-afnantayem\data\sample.csv")

# %%
print("Shape:", df.shape)
# Out:
# Shape: (5, 3)

# %%
print(df.head())
# Out:
#     name  score  passed
# 0  Alice     85    True
# 1    Bob     72    True
# 2  Carol     60   False
# 3  Diana     91    True
# 4    Eve     45   False

# %%
print(df.describe())
# Out:
#            score
# count   5.000000
# mean   70.600000
# std    18.662797
# min    45.000000
# 25%    60.000000
# 50%    72.000000
# 75%    85.000000
# max    91.000000
